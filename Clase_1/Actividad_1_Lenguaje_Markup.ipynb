# %% [markdown]
# # Actividades

# %% [markdown]
# ## Actividad 1

# %% [markdown]
#   Creá tu propio bloque de texto. Utiliza:
#   - formatos de texto
#   - links
#   - al menos una imagen de tu carpeta Drive

# %% [markdown]
# # **EJEMPLO DE BLOQUE DE TEXTO**
#
# Los bloques de texto son una herramienta muy útil en Colab, puesto que nos permite realizar anotaciones entre bloques de código. Asimismo, se pueden colocar [links](https://github.com/gafitabaires/TT-2C2025-Data-Analitycs-Notebooks) e inclusive carar imágenes que puedan facilitar el aprendizaje.
# ![introimag.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## Actividad 2

# %% [markdown]
# Creá un bloque de código con un programa que pida un número por teclado, y responda si es par o impar. Ejecutalo.

# %%
num = input("Ingresa un número: ")
num = int(num)
if num % 2 == 0:
    print("El número ingresado es par")
else:
    print("El número ingresado es impar")
# Out:
# Ingresa un número: 20
# El número ingresado es par
